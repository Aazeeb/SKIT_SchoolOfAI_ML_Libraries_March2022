# %%
#DataFrame vs Series

# %%
#A pandas series is a one-dimensional data structure
#A pandas dataframe is a two-dimensional data-structure that can be thought of as a spreadsheet. 
#A dataframe can also be thought of as a combination of two or more series.

# %%
#1.Series- 1D - [Column]
#2.DataFrame - 2D - [Rows*Column]

#Series is similar to numpy array, but there are a few differences
#In a series, you can have your own labeled index
#If there are missign values in numpy array, we will not be able to detect them
#In a series, it will return a NaN values

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a=np.array([1,2,3,4,5])
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
a[0]
# Out:
# 1

# %%
type(a)
# Out:
# numpy.ndarray

# %%
s=pd.Series(data=a)
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s[0]
# Out:
# 1

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
#creating a series using fancy labeling and a list
list1=[10,30,23,45,67]
labels=['v','w','x','y','z']
s1=pd.Series(data=list1,index=labels)
s1
# Out:
# v    10
# w    30
# x    23
# y    45
# z    67
# dtype: int64

# %%
#create a series using a numpy array, use np.arange() to create the array
#use a fancy index for the series

# %%
arr1=np.arange(10,25,3)
arr1
# Out:
# array([10, 13, 16, 19, 22])

# %%
names=['John','Jack','Jude','Juliet','Jones']

# %%
s2=pd.Series(data=arr1,index=names)
s2
# Out:
# John      10
# Jack      13
# Jude      16
# Juliet    19
# Jones     22
# dtype: int64

# %%
s2['Jack']
# Out:
# 13

# %%
s2['Jones']
# Out:
# 22

# %%
#create a series using a numpy array,
# use np.random.randint() to create the array of 8 elements between 25 and 40
#use a fancy index for the series, specify Indian state names
