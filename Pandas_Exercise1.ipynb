# %% [markdown]
# Step 1. Import the necessary libraries and check for its version

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.1.5'

# %% [markdown]
# Step 2. Import dataset from the address below <br>
# Step 3. Create a dataframe and assign it to a variable

# %%
url= 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

# %%
df = pd.read_table(url)

# %%
df
# Out:
#       order_id  ...  item_price
# 0            1  ...      $2.39
# 1            1  ...      $3.39
# 2            1  ...      $3.39
# 3            1  ...      $2.39
# 4            2  ...     $16.98
# ...        ...  ...         ...
# 4617      1833  ...     $11.75
# 4618      1833  ...     $11.75
# 4619      1834  ...     $11.25
# 4620      1834  ...      $8.75
# 4621      1834  ...      $8.75
#
# [4622 rows x 5 columns]

# %%
df = pd.read_table('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv')

# %%
#alternate way to create a dataframe
df1= pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep="\t")
df1
# Out:
#       order_id  ...  item_price
# 0            1  ...      $2.39
# 1            1  ...      $3.39
# 2            1  ...      $3.39
# 3            1  ...      $2.39
# 4            2  ...     $16.98
# ...        ...  ...         ...
# 4617      1833  ...     $11.75
# 4618      1833  ...     $11.75
# 4619      1834  ...     $11.25
# 4620      1834  ...      $8.75
# 4621      1834  ...      $8.75
#
# [4622 rows x 5 columns]

# %% [markdown]
# See the first/last n rows

# %%
df.head()
# Out:
#    order_id  ...  item_price
# 0         1  ...      $2.39
# 1         1  ...      $3.39
# 2         1  ...      $3.39
# 3         1  ...      $2.39
# 4         2  ...     $16.98
#
# [5 rows x 5 columns]

# %%
df.head(10)
# Out:
#    order_id  ...  item_price
# 0         1  ...      $2.39
# 1         1  ...      $3.39
# 2         1  ...      $3.39
# 3         1  ...      $2.39
# 4         2  ...     $16.98
# 5         3  ...     $10.98
# 6         3  ...      $1.69
# 7         4  ...     $11.75
# 8         4  ...      $9.25
# 9         5  ...      $9.25
#
# [10 rows x 5 columns]

# %%
df.head(2)
# Out:
#    order_id  quantity  ... choice_description item_price
# 0         1         1  ...                NaN     $2.39
# 1         1         1  ...       [Clementine]     $3.39
#
# [2 rows x 5 columns]

# %%
df.tail()
# Out:
#       order_id  ...  item_price
# 4617      1833  ...     $11.75
# 4618      1833  ...     $11.75
# 4619      1834  ...     $11.25
# 4620      1834  ...      $8.75
# 4621      1834  ...      $8.75
#
# [5 rows x 5 columns]

# %%
df.tail(2)
# Out:
#       order_id  ...  item_price
# 4620      1834  ...      $8.75
# 4621      1834  ...      $8.75
#
# [2 rows x 5 columns]

# %% [markdown]
# Slicing between the rows

# %%
df[3:10]
# Out:
#    order_id  ...  item_price
# 3         1  ...      $2.39
# 4         2  ...     $16.98
# 5         3  ...     $10.98
# 6         3  ...      $1.69
# 7         4  ...     $11.75
# 8         4  ...      $9.25
# 9         5  ...      $9.25
#
# [7 rows x 5 columns]

# %%
df[12:16]
# Out:
#     order_id  ...  item_price
# 12         6  ...      $8.75
# 13         7  ...     $11.25
# 14         7  ...      $4.45
# 15         8  ...      $2.39
#
# [4 rows x 5 columns]

# %%
df[20:25]
# Out:
#     order_id  ...  item_price
# 20        10  ...      $4.45
# 21        11  ...      $8.99
# 22        11  ...      $3.39
# 23        12  ...     $10.98
# 24        12  ...      $3.39
#
# [5 rows x 5 columns]

# %% [markdown]
# show each column individually

# %%
df['item_name']
# Out:
# 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: object

# %%
df['item_name'].head()
# Out:
# 0             Chips and Fresh Tomato Salsa
# 1                                     Izze
# 2                         Nantucket Nectar
# 3    Chips and Tomatillo-Green Chili Salsa
# 4                             Chicken Bowl
# Name: item_name, dtype: object

# %%
df['item_price']
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object

# %% [markdown]
# Usage of iloc operator<br>
# iloc-integer index location

# %%
df.iloc[2:6,2:4]
# Out:
#                                item_name                                 choice_description
# 2                       Nantucket Nectar                                            [Apple]
# 3  Chips and Tomatillo-Green Chili Salsa                                                NaN
# 4                           Chicken Bowl  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# 5                           Chicken Bowl  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...

# %% [markdown]
# display dataframe bewtween 15th and 22nd row.. and 3rd and 6th column

# %%
df.iloc[15:22,3:6]
# Out:
#                                    choice_description item_price
# 15                                                NaN     $2.39
# 16  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...     $8.49
# 17  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...     $8.49
# 18                                           [Sprite]     $2.18
# 19  [Tomatillo Red Chili Salsa, [Fajita Vegetables...     $8.75
# 20                                                NaN     $4.45
# 21  [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...     $8.99

# %% [markdown]
# Number of records int he dataset

# %%
df.shape
# Out:
# (4622, 5)

# %%
df.shape[0]
# Out:
# 4622

# %%
df.shape[1]
# Out:
# 5

# %%
df.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %% [markdown]
# Display the names of hte column

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# find the index of the dataframe

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# Display the duplicated values and drop them

# %%
df[df.duplicated()].shape
# Out:
# (59, 5)

# %%
df=df.drop_duplicates()
df
# Out:
#       order_id  ...  item_price
# 0            1  ...      $2.39
# 1            1  ...      $3.39
# 2            1  ...      $3.39
# 3            1  ...      $2.39
# 4            2  ...     $16.98
# ...        ...  ...         ...
# 4617      1833  ...     $11.75
# 4618      1833  ...     $11.75
# 4619      1834  ...     $11.25
# 4620      1834  ...      $8.75
# 4621      1834  ...      $8.75
#
# [4563 rows x 5 columns]

# %%
4622-59
# Out:
# 4563

# %% [markdown]
# Create a subdataframe from an existing one

# %%
df2=df.head(20)

# %%
df2.shape
# Out:
# (20, 5)

# %%
df2.head()
# Out:
#    order_id  ...  item_price
# 0         1  ...      $2.39
# 1         1  ...      $3.39
# 2         1  ...      $3.39
# 3         1  ...      $2.39
# 4         2  ...     $16.98
#
# [5 rows x 5 columns]

# %%
df3=df.iloc[5:20,2:6]

# %%
df3
# Out:
#                                 item_name  ... item_price
# 5                            Chicken Bowl  ...    $10.98
# 6                           Side of Chips  ...     $1.69
# 7                           Steak Burrito  ...    $11.75
# 8                        Steak Soft Tacos  ...     $9.25
# 9                           Steak Burrito  ...     $9.25
# 10                    Chips and Guacamole  ...     $4.45
# 11                   Chicken Crispy Tacos  ...     $8.75
# 12                     Chicken Soft Tacos  ...     $8.75
# 13                           Chicken Bowl  ...    $11.25
# 14                    Chips and Guacamole  ...     $4.45
# 15  Chips and Tomatillo-Green Chili Salsa  ...     $2.39
# 16                        Chicken Burrito  ...     $8.49
# 17                        Chicken Burrito  ...     $8.49
# 18                            Canned Soda  ...     $2.18
# 19                           Chicken Bowl  ...     $8.75
#
# [15 rows x 3 columns]

# %%
df3.shape
# Out:
# (15, 3)

# %% [markdown]
# In the orginal dataset, which was the most orderd item? <br>and how many times was it ordered

# %%
df['item_name'].value_counts()
# Out:
# Chicken Bowl                             717
# Chicken Burrito                          546
# Chips and Guacamole                      474
# Steak Burrito                            365
# Canned Soft Drink                        290
# Steak Bowl                               210
# Chips                                    208
# Bottled Water                            155
# Chicken Soft Tacos                       111
# Chicken Salad Bowl                       110
# Chips and Fresh Tomato Salsa             110
# Canned Soda                              102
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          90
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             65
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %%
df['item_name'].value_counts().head(1)
# Out:
# Chicken Bowl    717
# Name: item_name, dtype: int64

# %% [markdown]
# For the most ordered item, how may items were ordered

# %%
df['item_name'].value_counts().head(1)['Chicken Bowl']
# Out:
# 717

# %% [markdown]
# What was the most ordered item in the choice-decription column

# %%
df['choice_description'].value_counts().head(1)
# Out:
# [Diet Coke]    133
# Name: choice_description, dtype: int64

# %% [markdown]
# How many items were ordered in total

# %%
df['quantity'].sum()
# Out:
# 4913

# %% [markdown]
# Get the details of the highest ordered item

# %%
qmax=df['quantity'].max()
qmax
# Out:
# 15

# %%
df[df['quantity']==qmax]
# Out:
#       order_id  quantity  ... choice_description item_price
# 3598      1443        15  ...                NaN    $44.25
#
# [1 rows x 5 columns]

# %% [markdown]
# How much was revenue for the period in the dataset

# %%
revenue= (df['quantity']*df['item_price'])
revenue
# Out:
# 0               $2.39
# 1               $3.39
# 2               $3.39
# 3               $2.39
# 4       $16.98 $16.98
#              ...
# 4617           $11.75
# 4618           $11.75
# 4619           $11.25
# 4620            $8.75
# 4621            $8.75
# Length: 4563, dtype: object

# %%
revenue.sum()
# Out:
# '$2.39 $3.39 $3.39 $2.39 $16.98 $16.98 $10.98 $1.69 $11.75 $9.25 $9.25 $4.45 $8.75 $8.75 $11.25 $4.45 $2.39 $8.49 $8.49 $2.18 $2.18 $8.75 $4.45 $8.99 $3.39 $10.98 $3.39 $2.39 $8.49 $8.99 $1.09 $8.49 $2.39 $8.99 $1.69 $8.99 $1.09 $8.75 $8.75 $4.45 $2.95 $11.75 $2.15 $4.45 $11.25 $11.75 $8.75 $10.98 $8.99 $3.39 $8.99 $3.99 $8.99 $2.18 $2.18 $10.98 $1.09 $8.99 $2.39 $9.25 $11.25 $11.75 $2.15 $4.45 $9.25 $11.25 $8.75 $8.99 $8.99 $3.39 $8.99 $10.98 $8.99 $1.69 $8.99 $3.99 $8.75 $4.45 $8.75 $8.75 $2.15 $8.75 $11.25 $2.15 $9.25 $8.75 $8.75 $9.25 $8.49 $8.99 $1.09 $9.25 $2.95 $11.75 $11.75 $9.25 $11.75 $4.45 $9.25 $4.45 $11.75 $8.75 $8.75 $4.45 $8.99 $8.99 $3.99 $8.49 $3.39 $8.99 $1.09 $9.25 $4.45 $8.75 $2.95 $4.45 $2.39 $8.49 $8.99 $8.49 $1.09 $8.99 $3.99 $8.75 $9.25 $4.45 $11.25 $4.45 $8.99 $1.09 $9.25 $2.95 $4.45 $11.75 $4.45 $8.49 $2.39 $10.98 $22.50 $22.50 $11.75 $4.45 $11.25 $4.45 $11.25 $4.45 $11.25 $11.25 $11.75 $9.25 $4.45 $11.48 $17.98 $17.98 $1.69 $17.50 $17.50 $4.45 $8.49 $2.39 $
# ...

# %%
df.head()
# Out:
#    order_id  ...  item_price
# 0         1  ...      $2.39
# 1         1  ...      $3.39
# 2         1  ...      $3.39
# 3         1  ...      $2.39
# 4         2  ...     $16.98
#
# [5 rows x 5 columns]

# %%
df['item_price'].dtype
# Out:
# dtype('O')

# %%
df['item_price'].head()
# Out:
# 0     $2.39
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98
# Name: item_price, dtype: object

# %%
df['item_price']=df['item_price'].str.replace('$','').astype(float)

# %%
df['item_price'].head()
# Out:
# 0     2.39
# 1     3.39
# 2     3.39
# 3     2.39
# 4    16.98
# Name: item_price, dtype: float64

# %%
df['item_price'].dtype
# Out:
# dtype('float64')

# %%
revenue= (df['quantity']*df['item_price'])
revenue
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       33.96
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Length: 4563, dtype: float64

# %%
revenue.sum()
# Out:
# 38914.11

# %% [markdown]
# How many orders were made in the period

# %%
df['order_id'].value_counts().count()
# Out:
# 1834

# %% [markdown]
# What is the average revenue amount per order

# %%
df['revenue']=df['quantity']*df['item_price']

# %%
df.head()
# Out:
#    order_id  quantity  ... item_price revenue
# 0         1         1  ...       2.39    2.39
# 1         1         1  ...       3.39    3.39
# 2         1         1  ...       3.39    3.39
# 3         1         1  ...       2.39    2.39
# 4         2         2  ...      16.98   33.96
#
# [5 rows x 6 columns]

# %%
group_o=df.groupby(by=['order_id']).sum()
group_o
# Out:
#           quantity  item_price  revenue
# order_id
# 1                4       11.56    11.56
# 2                2       16.98    33.96
# 3                2       12.67    12.67
# 4                2       21.00    21.00
# 5                2       13.70    13.70
# ...            ...         ...      ...
# 1830             2       23.00    23.00
# 1831             3       12.90    12.90
# 1832             2       13.20    13.20
# 1833             2       23.50    23.50
# 1834             3       28.75    28.75
#
# [1834 rows x 3 columns]

# %%
group_o.mean()
# Out:
# quantity       2.678844
# item_price    18.635360
# revenue       21.218162
# dtype: float64

# %%
group_o.mean()['revenue']
# Out:
# 21.21816248636858

# %% [markdown]
# How many different items are sold

# %%
df['item_name'].value_counts().count()
# Out:
# 50

# %% [markdown]
# How many orders have revenue less than 10 dollars

# %%
df[df['revenue']<10].value_counts().count()
# Out:
# 2206
